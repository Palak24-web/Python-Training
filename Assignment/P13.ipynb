# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak24-web/Python-Training/blob/main/Assignment/P13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stones = int(input("Enter number of stones: "))

i = 1

total = 0

while True:
  total += i
  if total >= stones:
    print("Suresh won")
    break

  total += 2*1
  if total >= stones:
    print("Ramesh won")
    break

i = i + 1
# Out:
# Enter number of stones: 13
# Suresh won
