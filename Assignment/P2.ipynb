# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak24-web/Python-Training/blob/main/Assignment/P2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter first number: "))

b=int(input("Enter second number: "))

c=int(input("Enter third number: "))

max = "first number" if (a > b and a > c) else "Second number" if b > c else "Third number"

print("Greatest number is: ",max)
# Out:
# Enter first number: 1
# Enter second number: 2
# Enter third number: 3
# Greatest number is:  Third number
