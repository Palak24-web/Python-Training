# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak24-web/Python-Training/blob/main/Assignment/P14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
m = int(input("Enter number:"))
for i in range(m):
  for j in range(i+1):
    print("#",end = "")
  print("\n")
# Out:
# Enter number:4
# #
#
# ##
#
# ###
#
# ####
