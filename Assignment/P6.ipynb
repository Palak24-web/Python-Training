# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak24-web/Python-Training/blob/main/Assignment/P6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reverse(k):
  rev = 0
  while k > 0:
    digit = k % 10
    rev = rev * 10 + digit
    k = k // 10
  return rev

n = int(input("Enter number: "))

for i in range(n):
  a = int(input("Enter first number: "))
  b = int(input("Enter second number: "))
  arev = reverse(a)
  brev = reverse(b)
  sum = arev + brev
  sumrev = reverse(sum)
  print(f"final output is {sumrev}")
# Out:
# Enter number: 3
# Enter first number: 48
# Enter second number: 569
# final output is 9401
# Enter first number: 65
# Enter second number: 85
# final output is 411
# Enter first number: 54
# Enter second number: 63
# final output is 18
