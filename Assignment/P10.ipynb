# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak24-web/Python-Training/blob/main/Assignment/P10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
minSkill = 100

skills = []

peoples = int(input("Enter number of people: "))

for i in range(peoples):
  push = 6int(input(f"Enter person (i+1) skill: "))
  skills.append(push) #because it is not taking push directly in

for i in range(peoples):
  if skills[i] >= minSkill:
    print("Yes")
  else:
    print("No")
# Out:
# Enter number of people: 4
# Enter person (i+1) skill: 5
# Enter person (i+1) skill: 6
# Enter person (i+1) skill: 8
# Enter person (i+1) skill: 8
# No
# No
# No
# No
