# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak24-web/Python-Training/blob/main/Assignment/P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conversion program: Inches to Foot, Yard, Centimeter, Meter

inches = float(input("Enter value in inches: "))

foot = inches / 12
yard = inches / 36
centimeters = inches * 2.54
meter = inches / 39.37

print(f"\n{inches} inches is equal to:")
print(f"{foot} feet")
print(f"{yard} yards")
print(f"{centimeters} centimeters")
print(f"{meter} meters")
# Out:
# Enter value in inches: 15
#
# 15.0 inches is equal to:
# 1.25 feet
# 0.4166666666666667 yards
# 38.1 centimeters
# 0.38100076200152405 meters
